# %%
import numpy as np
import pandas as pd
import pyarrow.parquet as pq

# %%
def read_large_parquet(file_path, chunk_size=10000):
    parquet_file = pq.ParquetFile("./data/train.parquet")
    num_rows = parquet_file.metadata.num_rows
    num_chunks = num_rows // chunk_size + 1

    for i in range(num_chunks):
        table = parquet_file.read_row_group(i, columns=None)
        yield table.to_pandas()

# %%
for chunk in read_large_parquet('your_file.parquet'):
    # Process each chunk of data here
    print(chunk)
# Out:
#               id                            buildingblock1_smiles  \
# 0              0  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 1              1  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 2              2  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 3              3  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 4              4  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# ...          ...                                              ...
# 1048571  1048571  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 1048572  1048572  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 1048573  1048573  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 1048574  1048574  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 1048575  1048575  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
#
#         buildingblock2_smiles    buildingblock3_smiles  \
# 0        C#CCOc1ccc(CN)cc1.Cl  Br.Br.NCC1CCCN1c1cccnn1
# 1        C#CCOc1ccc(CN)cc1.Cl  Br.Br.NCC1CCCN1c1cccnn1
# ...
